# %% [markdown]
# # Sage Shaw
#
# ### ME 571 - Spring 2018
#
# # HW 1 - Problem 4

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from random import random
import multiprocessing as mp

# %%
columns = ['Time', 'Processes', 'N', 'Error', 'colors']
data = pd.DataFrame(columns=columns)

def stats_from_timeit(timeit_result, procs, N, value, description):
    t = timeit_result.best
    data_row = {'Time': t, 'Processes': str(procs), 'N': N, 'Error': abs(value-np.pi)}
    return pd.Series(data=data_row, name=description)

# %% [markdown]
# # Single Processor

# %%
def single_calc(nums):
    #r = [x**2 + y**2 for x,y in nums]
    #hits = [1> radius for radius in r]
    #return 4 * sum(hits)/len(nums)
    return 4 * sum([x**2 + y**2 <= 1 for x, y in nums]) /len(nums)

# %%
nums = [(random(),random()) for i in range(10**4)]
single_calc(nums) - np.pi
# Out:
# 0.010007346410207063

# %%
Ns = [10**i for i in range(2,7)]
val = 0

for N in Ns:
    nums = [(random(),random()) for i in range(N)]
    my_time = %timeit -o pass; global val; val = single_calc(nums)
    data = data.append(stats_from_timeit(my_time, 'Single', N, val, 'Single'))
# Out:
# 10000 loops, best of 3: 39.5 µs per loop
# 1000 loops, best of 3: 397 µs per loop
# 100 loops, best of 3: 4 ms per loop
# 10 loops, best of 3: 41 ms per loop
# 1 loop, best of 3: 420 ms per loop

# %%
data
# Out:
#             Time Processes        N     Error  colors
# Single  0.000040    Single      100  0.098407     NaN
# Single  0.000397    Single     1000  0.014407     NaN
# Single  0.004002    Single    10000  0.023993     NaN
# Single  0.040972    Single   100000  0.009967     NaN
# Single  0.419504    Single  1000000  0.003427     NaN

# %% [markdown]
# ## Multiprocessor

# %%
def calc_pi(proc_num, nums, ret_arr):
    pi = 4 * sum([x**2 + y**2 <= 1 for x, y in nums]) / len(nums)
    ret_arr[proc_num] = pi
    return

def multi_calc(nums, p):
    ret_arr = mp.Array('f', [0]*p)
    sublists = [nums[i::p] for i in range(p)]
    jobs = [mp.Process(target=calc_pi, args=(i, sublist, ret_arr) ) for i, sublist in enumerate(sublists)]
        
    for job in jobs: job.start() 
    for job in jobs: job.join() 
    
    return sum(ret_arr)/p

# %%
Ns = [10**i for i in range(2,8)]
Ps = [2**i for i in range(7)]
val = 0

for N in Ns:
    for P in Ps:
        for x in [0,1]:
            print('Running N: %d     P: %d' %(N,P))
            nums = [(random(),random()) for i in range(N)]
            my_time = %timeit -o pass; global val; val = multi_calc(nums,P)
            data = data.append(stats_from_timeit(my_time, str(P) + ' Processes', N, val, 'Parallel'))
# Out:
# Running N: 100     P: 1
# 100 loops, best of 3: 5.47 ms per loop
# Running N: 100     P: 1
# 100 loops, best of 3: 5.56 ms per loop
# Running N: 1000     P: 1
# 100 loops, best of 3: 6.01 ms per loop
# Running N: 1000     P: 1
# 100 loops, best of 3: 6.06 ms per loop
# Running N: 10000     P: 1
# 100 loops, best of 3: 11.3 ms per loop
# Running N: 10000     P: 1
# 100 loops, best of 3: 11.1 ms per loop
# Running N: 100000     P: 1
# 10 loops, best of 3: 61.2 ms per loop
# Running N: 100000     P: 1
# 10 loops, best of 3: 62.1 ms per loop
# Running N: 1000000     P: 1
# 1 loop, best of 3: 547 ms per loop
# Running N: 1000000     P: 1
# 1 loop, best of 3: 539 ms per loop
# Running N: 10000000     P: 1
# 1 loop, best of 3: 5.25 s per loop
# Running N: 10000000     P: 1
# 1 loop, best of 3: 5.33 s per loop
# Running N: 100     P: 2
# 100 loops, best of 3: 8.6 ms per loop
# Running N: 100     P: 2
# 100 loops, best of 3: 8.39 ms per loop
# Running N: 1000     P: 2
# 100 loops, best of 3: 8.66 ms per loop
# Running N: 1000     P: 2
# 100 loops, best of 3: 8.73 ms per loop
# Running N: 10000     P: 2
# 100 loops, best of 3: 11.9 ms per loop
# Running N: 10000     P: 2
# 100 loops, best of 3: 12 ms per loop
# Running N: 100000     P: 2
# 10 loops, best of 3: 43.4 ms per loop
# Running N: 100000     P: 2
# 10 loops, best of 3: 44.6 ms per loop
# Running N: 1000000     P: 2
# 1 loop, best of 3: 379 ms per loop
# Running N: 1000000     P: 2
# 1 loop, best of 3: 349 ms per loop
# Running N: 10000000     P: 2
# 1 loop, best of 3: 3.33 s per loop
# Running N: 10000000     P: 2
# 1 loop, best of 3: 3.56 s per loop
# Running N: 100     P: 4
# 100 loops, best of 3: 13.9 ms per loop
# Running N: 100     P: 4
# 100 loops, best of 3: 13.7 ms per loop
# Running N: 1000     P: 4
# 100 loops, best of 3: 14.1 ms per loop
# Running N: 1000     P: 4
# 100 loops, best of 3: 14.2 ms per loop
# Running N: 10000     P: 4
# 100 loops, best of 3: 16.6 ms per loop
# Running N: 10000     P: 4
# 100 loops, best of 3: 16.5 ms per loop
# Running N: 100000     P: 4
# 10 loops, best of 3: 38.5 ms per loop
# Running N: 100000     P: 4
# 10 loops, best of 3: 40.2 ms per loop
# Running N: 1000000     P: 4
# 1 loop, best of 3: 295 ms per loop
# Running N: 1000000     P: 4
# 1 loop, best of 3: 270 ms per loop
# Running N: 10000000     P: 4
# 1 loop, best of 3: 2.6 s per loop
# Running N: 10000000     P: 4
# 1 loop, best of 3: 2.63 s per loop
# Running N: 100     P: 8
# 10 loops, best of 3: 21.9 ms per loop
# Running N: 100     P: 8
# 10 loops, best of 3: 21 ms per loop
# Running N: 1000     P: 8
# 10 loops, best of 3: 26.1 ms per loop
# Running N: 1000     P: 8
# 10 loops, best of 3: 21.1 ms per loop
# Running N: 10000     P: 8
# 10 loops, best of 3: 24.4 ms per loop
# Running N: 10000     P: 8
# 10 loops, best of 3: 25.1 ms per loop
# Running N: 100000     P: 8
# 10 loops, best of 3: 49.4 ms per loop
# Running N: 100000     P: 8
# 10 loops, best of 3: 50.3 ms per loop
# Running N: 1000000     P: 8
# 1 loop, best of 3: 253 ms per loop
# Running N: 1000000     P: 8
# 1 loop, best of 3: 252 ms per loop
# Running N: 10000000     P: 8
# 1 loop, best of 3: 2.47 s per loop
# Running N: 10000000     P: 8
# 1 loop, best of 3: 2.45 s per loop
# Running N: 100     P: 16
# 10 loops, best of 3: 41.7 ms per loop
# Running N: 100     P: 16
# 10 loops, best of 3: 41.8 ms per loop
# Running N: 1000     P: 16
# 10 loops, best of 3: 41 ms per loop
# Running N: 1000     P: 16
# 10 loops, best of 3: 40.5 ms per loop
# Running N: 10000     P: 16
# 10 loops, best of 3: 45.3 ms per loop
# Running N: 10000     P: 16
# 10 loops, best of 3: 45 ms per loop
# Running N: 100000     P: 16
# 10 loops, best of 3: 75.8 ms per loop
# Running N: 100000     P: 16
# 10 loops, best of 3: 75.2 ms per loop
# Running N: 1000000     P: 16
# 1 loop, best of 3: 312 ms per loop
# Running N: 1000000     P: 16
# 1 loop, best of 3: 331 ms per loop
# Running N: 10000000     P: 16
# 1 loop, best of 3: 3.18 s per loop
# Running N: 10000000     P: 16
# 1 loop, best of 3: 3.18 s per loop
# Running N: 100     P: 32
# 10 loops, best of 3: 82.5 ms per loop
# Running N: 100     P: 32
# 10 loops, best of 3: 78.8 ms per loop
# Running N: 1000     P: 32
# 10 loops, best of 3: 83.4 ms per loop
# Running N: 1000     P: 32
# 10 loops, best of 3: 82.8 ms per loop
# Running N: 10000     P: 32
# 10 loops, best of 3: 85.6 ms per loop
# Running N: 10000     P: 32
# 10 loops, best of 3: 91.8 ms per loop
# Running N: 100000     P: 32
# 10 loops, best of 3: 141 ms per loop
# Running N: 100000     P: 32
# 10 loops, best of 3: 144 ms per loop
# Running N: 1000000     P: 32
# 1 loop, best of 3: 597 ms per loop
# Running N: 1000000     P: 32
# 1 loop, best of 3: 554 ms per loop
# Running N: 10000000     P: 32
# 1 loop, best of 3: 5.78 s per loop
# Running N: 10000000     P: 32
# 1 loop, best of 3: 5.78 s per loop
# Running N: 100     P: 64
# 1 loop, best of 3: 212 ms per loop
# Running N: 100     P: 64
# 1 loop, best of 3: 212 ms per loop
# Running N: 1000     P: 64
# 1 loop, best of 3: 207 ms per loop
# Running N: 1000     P: 64
# 1 loop, best of 3: 176 ms per loop
# Running N: 10000     P: 64
# 10 loops, best of 3: 179 ms per loop
# Running N: 10000     P: 64
# 10 loops, best of 3: 181 ms per loop
# Running N: 100000     P: 64
# 1 loop, best of 3: 255 ms per loop
# Running N: 100000     P: 64
# 1 loop, best of 3: 270 ms per loop
# Running N: 1000000     P: 64
# 1 loop, best of 3: 991 ms per loop
# Running N: 1000000     P: 64
# 1 loop, best of 3: 932 ms per loop
# Running N: 10000000     P: 64
# 1 loop, best of 3: 10.1 s per loop
# Running N: 10000000     P: 64
# 1 loop, best of 3: 9.93 s per loop

# %%
data
# Out:
#                Time     Processes         N     Error  colors
# Single     0.000040        Single       100  0.098407     NaN
# Single     0.000397        Single      1000  0.014407     NaN
# Single     0.004002        Single     10000  0.023993     NaN
# Single     0.040972        Single    100000  0.009967     NaN
# Single     0.419504        Single   1000000  0.003427     NaN
# Parallel   0.005474   1 Processes       100  0.021593     NaN
# Parallel   0.005556   1 Processes       100  0.101593     NaN
# Parallel   0.006014   1 Processes      1000  0.078407     NaN
# Parallel   0.006063   1 Processes      1000  0.010407     NaN
# Parallel   0.011338   1 Processes     10000  0.011207     NaN
# Parallel   0.011109   1 Processes     10000  0.025193     NaN
# Parallel   0.061209   1 Processes    100000  0.014913     NaN
# Parallel   0.062103   1 Processes    100000  0.001153     NaN
# Parallel   0.546697   1 Processes   1000000  0.002917     NaN
# Parallel   0.538986   1 Processes   1000000  0.001109     NaN
# Parallel   5.250345   1 Processes  10000000  0.000457     NaN
# Parallel   5.331123   1 Processes  10000000  0.000501     NaN
# Parallel   0.008598   2 Processes       100  0.058407     NaN
# Parallel   0.008393   2 Processes       100  0.141593     NaN
# Parallel   0.008663   2 Processes      1000  0.013593     NaN
# Parallel   0.008735   2 Processes      1000  0.049593     NaN
# Parallel   0.011916   2 Processes     10000  0.007607     NaN
# Parallel   0.012021   2 Processes     10000  0.008793     NaN
# Parallel   0.043435   2 Processes    100000  0.006873     NaN
# Parallel   0.044604   2 Processes    100000  0.000887     NaN
# Parallel   0.379158   2 Processes   1000000  0.002519     NaN
# Parallel   0.348908   2 Processes   1000000  0.003137     NaN
# Parallel   3.334141   2 Processes  10000000  0.000162     NaN
# Parallel   3.562449   2 Processes  10000000  0.000393     NaN
# Parallel   0.013885   4 Processes       100  0.098407     NaN
# ...             ...           ...       ...       ...     ...
# Parallel   0.075830  16 Processes    100000  0.003087     NaN
# Parallel   0.075219  16 Processes    100000  0.004993     NaN
# Parallel   0.312335  16 Processes   1000000  0.001759     NaN
# Parallel   0.330636  16 Processes   1000000  0.001397     NaN
# Parallel   3.177166  16 Processes  10000000  0.000317     NaN
# Parallel   3.176108  16 Processes  10000000  0.000352     NaN
# Parallel   0.082452  32 Processes       100  0.243824     NaN
# Parallel   0.078814  32 Processes       100  0.006176     NaN
# Parallel   0.083389  32 Processes      1000  0.076321     NaN
# Parallel   0.082800  32 Processes      1000  0.077329     NaN
# Parallel   0.085589  32 Processes     10000  0.023212     NaN
# Parallel   0.091793  32 Processes     10000  0.011610     NaN
# Parallel   0.141023  32 Processes    100000  0.000927     NaN
# Parallel   0.143612  32 Processes    100000  0.000367     NaN
# Parallel   0.597000  32 Processes   1000000  0.000807     NaN
# Parallel   0.554364  32 Processes   1000000  0.000657     NaN
# Parallel   5.780043  32 Processes  10000000  0.000236     NaN
# Parallel   5.779019  32 Processes  10000000  0.000745     NaN
# Parallel   0.211985  64 Processes       100  0.360343     NaN
# Parallel   0.211853  64 Processes       100  0.454093     NaN
# Parallel   0.206841  64 Processes      1000  0.011645     NaN
# Parallel   0.176184  64 Processes      1000  0.040551     NaN
# Parallel   0.179158  64 Processes     10000  0.022813     NaN
# Parallel   0.180700  64 Processes     10000  0.001149     NaN
# Parallel   0.254734  64 Processes    100000  0.000086     NaN
# Parallel   0.270372  64 Processes    100000  0.004287     NaN
# Parallel   0.990754  64 Processes   1000000  0.001339     NaN
# Parallel   0.932081  64 Processes   1000000  0.001211     NaN
# Parallel  10.081375  64 Processes  10000000  0.000764     NaN
# Parallel   9.929132  64 Processes  10000000  0.000441     NaN
#
# [89 rows x 5 columns]

# %%
colors = {
            'Single': 'yellow' ,
            '1 Processes': '#FF0033',
            '2 Processes': '#FF0066',
            '4 Processes': '#FF0099',
            '8 Processes': '#FF00CC',
            '16 Processes': '#FF00FF',
            '32 Processes': '#CC00FF',
            '64 Processes': '#000000',
            '128 Processes': '#000000',
            '512 Processes': '#000000'
         }

data['colors'] = data['Processes'].map(colors)

data.plot(kind='scatter', x='Time', y='Error', color=data['colors'], loglog=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3529fd8f4f64> in <module>()
#      12          }
#      13
# ---> 14 data['colors'] = data['Processes'].map(colors)
#      15
#      16 data['rbf':'r^3'].plot(kind='scatter', x='Time', y='Error', color=data['colors'], loglog=True)
#
# NameError: name 'data' is not defined

# %% [markdown]
# The Single Process in Serial runs are marked in yellow. The Parrallelized Processes move from red to purple as the number of processes increases. The black entries correspond to the Parallelized algorithm when it is ran on more processes than the number of cores on the machine.

# %% [markdown]
# # Analysis

# %% [markdown]
# The purple dots, coressponding to the Parallelized algorithm with a high processor count, seem to do the best. As the error decreases, the time increases less than it does for the more red dots. Some of the purple dots are clearly worse, but those are the instances when the processor count was higher than the number of cores on the machine.
#
# The red data points seem to be roughly linear but decreacing more slowly than the roughly linear purple points. This corresponds to a higher initialization cost (more costly for fewer data points i.e. less time) but a better growth rate as the number of points increases.
#
# While this is quite possibly the worst way to calculate $\pi$ it was fun!
